# %% [markdown]
# # CHALLENGE 1

# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# 4. Get the nearest city using the citipy module
from citipy import citipy

# Import the API key
from configW import weather_api_key

# %%
# 3. Create a new set of 2,000 random latitudes and longitude
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities. 6.1.5
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# 5. a. Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)# Starting URL for Weather Map API Call. 6.2.3
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0546ad5dbee13bad86394b7d864b452c

# %%
# 6. Retrieve the request information from the API call
# a. Create a list for holding the cities. 6.1.5
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# 6.b. Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters. We want the first iteration of the logging for each recorded response and the set to start at 1
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# 6.c. Loop through all the cities in the list 6.2.6.
for i, city in enumerate(cities):

        # Group cities in sets of 50 for logging purposes.(while grouping our records in sets of 50)
    if (i % 50 == 0 and i >= 50):
        #If the statement is true, then the set_count and the record_count are incremented by 1
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    #without enumerate() it was: city_url = url + "&q=" + cities[i]
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    #removing the blank spaces in the city name 
    # and concatenating the city name. This will find the corresponding weather data for the city 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #instead of finding the weather data for the first part of the city name
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.

    try:
        # Parse the JSON and retrieve data.
            #If there is no weather data for the city, i.e. , a <Response [404]> 
            #then there is no weather to retrieve and City not found. Skipping... is printed.
            # If there is weather data for the city, we will retrieve the latitude, longitude, 
            #maximum temperature, humidity, cloudiness, wind speed, and date and assign those values to variables
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        #We append the cities list with a dictionary for that city, 
        #where the key-value pairs are the values from our weather parameter
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        #Generally, it isn't good coding practice to add the pass statement to the except block. 
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | pevek
# Processing Record 3 of Set 1 | port macquarie
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | corrales
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | la rioja
# Processing Record 9 of Set 1 | penzance
# Processing Record 10 of Set 1 | balsas
# Processing Record 11 of Set 1 | huarmey
# Processing Record 12 of Set 1 | huazolotitlan
# City not found. Skipping...
# Processing Record 13 of Set 1 | faya
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | chuy
# Processing Record 16 of Set 1 | pontianak
# Processing Record 17 of Set 1 | kieta
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | dali
# Processing Record 20 of Set 1 | blackwater
# Processing Record 21 of Set 1 | geraldton
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | anadyr
# Processing Record 24 of Set 1 | souillac
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | banda aceh
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | high level
# Processing Record 29 of Set 1 | krasnogorskoye
# Processing Record 30 of Set 1 | korla
# Processing Record 31 of Set 1 | mafinga
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | biltine
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | saldanha
# Processing Record 37 of Set 1 | athabasca
# Processing Record 38 of Set 1 | nyurba
# Processing Record 39 of Set 1 | mon
# Processing Record 40 of Set 1 | kharan
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | tukan
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | thomaston
# Processing Record 45 of Set 1 | provideniya
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 1 | bose
# Processing Record 49 of Set 1 | college
# Processing Record 50 of Set 1 | lagunas
# Processing Record 1 of Set 2 | sobolevo
# Processing Record 2 of Set 2 | likasi
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | santa fe
# Processing Record 5 of Set 2 | kyabe
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | saint-augustin
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | kolomna
# Processing Record 12 of Set 2 | esperance
# Processing Record 13 of Set 2 | teguise
# Processing Record 14 of Set 2 | vardo
# Processing Record 15 of Set 2 | phumi samraong
# City not found. Skipping...
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | ilulissat
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | ust-nera
# Processing Record 22 of Set 2 | maceio
# Processing Record 23 of Set 2 | udachnyy
# Processing Record 24 of Set 2 | chippewa falls
# Processing Record 25 of Set 2 | bonito
# Processing Record 26 of Set 2 | aksha
# Processing Record 27 of Set 2 | lompoc
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | sainte-suzanne
# Processing Record 30 of Set 2 | beringovskiy
# Processing Record 31 of Set 2 | vostok
# Processing Record 32 of Set 2 | ryotsu
# Processing Record 33 of Set 2 | tezu
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | ha giang
# Processing Record 36 of Set 2 | san patricio
# Processing Record 37 of Set 2 | madaoua
# Processing Record 38 of Set 2 | thompson
# Processing Record 39 of Set 2 | victoria
# Processing Record 40 of Set 2 | ponta do sol
# Processing Record 41 of Set 2 | muros
# Processing Record 42 of Set 2 | eureka
# Processing Record 43 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 2 | margate
# Processing Record 45 of Set 2 | severobaykalsk
# Processing Record 46 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | vao
# Processing Record 49 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 2 | changqing
# Processing Record 1 of Set 3 | kununurra
# Processing Record 2 of Set 3 | qaqortoq
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | moussoro
# Processing Record 7 of Set 3 | norman wells
# Processing Record 8 of Set 3 | gusino
# Processing Record 9 of Set 3 | nador
# Processing Record 10 of Set 3 | lata
# Processing Record 11 of Set 3 | nizhniy odes
# Processing Record 12 of Set 3 | henties bay
# Processing Record 13 of Set 3 | carnarvon
# Processing Record 14 of Set 3 | nichinan
# Processing Record 15 of Set 3 | morondava
# Processing Record 16 of Set 3 | sable-sur-sarthe
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | concarneau
# Processing Record 19 of Set 3 | hambantota
# Processing Record 20 of Set 3 | cherskiy
# Processing Record 21 of Set 3 | bredasdorp
# Processing Record 22 of Set 3 | haines junction
# Processing Record 23 of Set 3 | zabaykalsk
# Processing Record 24 of Set 3 | neropolis
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | salinopolis
# Processing Record 27 of Set 3 | nuuk
# Processing Record 28 of Set 3 | muhlhausen
# Processing Record 29 of Set 3 | nikolskoye
# Processing Record 30 of Set 3 | nanortalik
# Processing Record 31 of Set 3 | hami
# Processing Record 32 of Set 3 | roald
# Processing Record 33 of Set 3 | bahce
# Processing Record 34 of Set 3 | akyab
# Processing Record 35 of Set 3 | kaputa
# Processing Record 36 of Set 3 | yeppoon
# Processing Record 37 of Set 3 | sawankhalok
# Processing Record 38 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 3 | inta
# Processing Record 40 of Set 3 | paamiut
# Processing Record 41 of Set 3 | fethiye
# Processing Record 42 of Set 3 | ostrovnoy
# Processing Record 43 of Set 3 | den helder
# Processing Record 44 of Set 3 | bodden town
# Processing Record 45 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 46 of Set 3 | yellowknife
# Processing Record 47 of Set 3 | dingle
# Processing Record 48 of Set 3 | port hardy
# Processing Record 49 of Set 3 | northam
# Processing Record 50 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | khatanga
# Processing Record 3 of Set 4 | puerto ayacucho
# Processing Record 4 of Set 4 | port elizabeth
# Processing Record 5 of Set 4 | saint george
# Processing Record 6 of Set 4 | san cristobal
# Processing Record 7 of Set 4 | lakheri
# Processing Record 8 of Set 4 | vestmannaeyjar
# Processing Record 9 of Set 4 | micheweni
# Processing Record 10 of Set 4 | ginir
# Processing Record 11 of Set 4 | ulladulla
# Processing Record 12 of Set 4 | praia da vitoria
# Processing Record 13 of Set 4 | castro
# Processing Record 14 of Set 4 | hofn
# Processing Record 15 of Set 4 | kavieng
# Processing Record 16 of Set 4 | buena vista
# Processing Record 17 of Set 4 | atuona
# Processing Record 18 of Set 4 | buala
# Processing Record 19 of Set 4 | kilindoni
# Processing Record 20 of Set 4 | sakakah
# Processing Record 21 of Set 4 | necochea
# Processing Record 22 of Set 4 | panzhihua
# Processing Record 23 of Set 4 | srednekolymsk
# Processing Record 24 of Set 4 | rock sound
# Processing Record 25 of Set 4 | ballina
# Processing Record 26 of Set 4 | lafiagi
# Processing Record 27 of Set 4 | grand-lahou
# Processing Record 28 of Set 4 | cayenne
# Processing Record 29 of Set 4 | tuktoyaktuk
# Processing Record 30 of Set 4 | ugra
# Processing Record 31 of Set 4 | van
# Processing Record 32 of Set 4 | avarua
# Processing Record 33 of Set 4 | dharchula
# Processing Record 34 of Set 4 | saskylakh
# Processing Record 35 of Set 4 | barcelos
# Processing Record 36 of Set 4 | hithadhoo
# Processing Record 37 of Set 4 | yingshang
# City not found. Skipping...
# Processing Record 38 of Set 4 | carutapera
# Processing Record 39 of Set 4 | tucano
# Processing Record 40 of Set 4 | komsomolskiy
# Processing Record 41 of Set 4 | cumpas
# Processing Record 42 of Set 4 | chaplynka
# Processing Record 43 of Set 4 | erdenet
# Processing Record 44 of Set 4 | uncia
# Processing Record 45 of Set 4 | la ronge
# Processing Record 46 of Set 4 | kpalime
# Processing Record 47 of Set 4 | sabya
# Processing Record 48 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 4 | rawson
# Processing Record 1 of Set 5 | solnechnyy
# Processing Record 2 of Set 5 | yerbogachen
# Processing Record 3 of Set 5 | ibra
# Processing Record 4 of Set 5 | araouane
# Processing Record 5 of Set 5 | tautira
# Processing Record 6 of Set 5 | pangnirtung
# Processing Record 7 of Set 5 | alenquer
# Processing Record 8 of Set 5 | puerto ayora
# Processing Record 9 of Set 5 | santa cruz
# Processing Record 10 of Set 5 | livingston
# Processing Record 11 of Set 5 | pisco
# Processing Record 12 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 5 | dakoro
# Processing Record 14 of Set 5 | mahebourg
# Processing Record 15 of Set 5 | santiago del estero
# Processing Record 16 of Set 5 | santa cruz de la palma
# Processing Record 17 of Set 5 | porto belo
# Processing Record 18 of Set 5 | ascension
# Processing Record 19 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 5 | kahului
# Processing Record 21 of Set 5 | kungurtug
# Processing Record 22 of Set 5 | kruisfontein
# Processing Record 23 of Set 5 | upernavik
# Processing Record 24 of Set 5 | kamenka
# Processing Record 25 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 26 of Set 5 | nakatunguru
# Processing Record 27 of Set 5 | wawa
# Processing Record 28 of Set 5 | mattru
# Processing Record 29 of Set 5 | adre
# Processing Record 30 of Set 5 | wasilla
# Processing Record 31 of Set 5 | te anau
# Processing Record 32 of Set 5 | mandurah
# Processing Record 33 of Set 5 | flin flon
# Processing Record 34 of Set 5 | san carlos de bariloche
# Processing Record 35 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 5 | saint-philippe
# Processing Record 37 of Set 5 | honiara
# Processing Record 38 of Set 5 | kurilsk
# Processing Record 39 of Set 5 | kaitangata
# Processing Record 40 of Set 5 | sao filipe
# Processing Record 41 of Set 5 | genhe
# Processing Record 42 of Set 5 | arraial do cabo
# Processing Record 43 of Set 5 | banfora
# Processing Record 44 of Set 5 | puerto penasco
# Processing Record 45 of Set 5 | sapao
# City not found. Skipping...
# Processing Record 46 of Set 5 | itarema
# Processing Record 47 of Set 5 | port augusta
# Processing Record 48 of Set 5 | ubauro
# Processing Record 49 of Set 5 | constitucion
# Processing Record 50 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 6 | meulaboh
# Processing Record 2 of Set 6 | saint-francois
# Processing Record 3 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 6 | severo-kurilsk
# Processing Record 5 of Set 6 | savinka
# Processing Record 6 of Set 6 | butaritari
# Processing Record 7 of Set 6 | kodiak
# Processing Record 8 of Set 6 | alyangula
# Processing Record 9 of Set 6 | laytown
# Processing Record 10 of Set 6 | avera
# Processing Record 11 of Set 6 | bilma
# Processing Record 12 of Set 6 | tuatapere
# Processing Record 13 of Set 6 | parbhani
# Processing Record 14 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 15 of Set 6 | mayo
# Processing Record 16 of Set 6 | saint anthony
# Processing Record 17 of Set 6 | isangel
# Processing Record 18 of Set 6 | sokoni
# Processing Record 19 of Set 6 | san rafael
# Processing Record 20 of Set 6 | whitehorse
# Processing Record 21 of Set 6 | zhigansk
# Processing Record 22 of Set 6 | chillicothe
# Processing Record 23 of Set 6 | lazaro cardenas
# Processing Record 24 of Set 6 | san miguelito
# Processing Record 25 of Set 6 | manyana
# Processing Record 26 of Set 6 | rumonge
# Processing Record 27 of Set 6 | padang
# Processing Record 28 of Set 6 | jalu
# Processing Record 29 of Set 6 | maragogi
# Processing Record 30 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 6 | taybad
# Processing Record 32 of Set 6 | dunedin
# Processing Record 33 of Set 6 | namatanai
# Processing Record 34 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 35 of Set 6 | salalah
# Processing Record 36 of Set 6 | chibombo
# Processing Record 37 of Set 6 | qaanaaq
# Processing Record 38 of Set 6 | bathsheba
# Processing Record 39 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 6 | williams lake
# Processing Record 42 of Set 6 | coatepec harinas
# Processing Record 43 of Set 6 | ostersund
# Processing Record 44 of Set 6 | bengkulu
# Processing Record 45 of Set 6 | pingliang
# Processing Record 46 of Set 6 | krupina
# Processing Record 47 of Set 6 | camaguey
# Processing Record 48 of Set 6 | sakaiminato
# Processing Record 49 of Set 6 | vila velha
# Processing Record 50 of Set 6 | sarangani
# Processing Record 1 of Set 7 | lebu
# Processing Record 2 of Set 7 | yekaterinogradskaya
# Processing Record 3 of Set 7 | hermosillo
# Processing Record 4 of Set 7 | daru
# Processing Record 5 of Set 7 | alice springs
# Processing Record 6 of Set 7 | balaipungut
# Processing Record 7 of Set 7 | jaguariaiva
# Processing Record 8 of Set 7 | linhares
# Processing Record 9 of Set 7 | santa ana
# Processing Record 10 of Set 7 | eten
# Processing Record 11 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 12 of Set 7 | dalvik
# Processing Record 13 of Set 7 | nantucket
# Processing Record 14 of Set 7 | verkhoyansk
# Processing Record 15 of Set 7 | porto novo
# Processing Record 16 of Set 7 | teya
# Processing Record 17 of Set 7 | cedar city
# Processing Record 18 of Set 7 | maamba
# Processing Record 19 of Set 7 | farafangana
# Processing Record 20 of Set 7 | rocha
# Processing Record 21 of Set 7 | port hedland
# Processing Record 22 of Set 7 | havoysund
# Processing Record 23 of Set 7 | flinders
# Processing Record 24 of Set 7 | bilibino
# Processing Record 25 of Set 7 | pandan
# Processing Record 26 of Set 7 | nikki
# Processing Record 27 of Set 7 | zverinogolovskoye
# Processing Record 28 of Set 7 | codrington
# Processing Record 29 of Set 7 | banyumas
# Processing Record 30 of Set 7 | camacha
# Processing Record 31 of Set 7 | aykino
# Processing Record 32 of Set 7 | iberia
# Processing Record 33 of Set 7 | severnoye
# Processing Record 34 of Set 7 | leningradskiy
# Processing Record 35 of Set 7 | westport
# Processing Record 36 of Set 7 | panguma
# Processing Record 37 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 7 | zaysan
# Processing Record 39 of Set 7 | san jeronimo
# Processing Record 40 of Set 7 | ca mau
# Processing Record 41 of Set 7 | fairbanks
# Processing Record 42 of Set 7 | natal
# Processing Record 43 of Set 7 | voi
# Processing Record 44 of Set 7 | tessalit
# Processing Record 45 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 7 | fort nelson
# Processing Record 47 of Set 7 | pauini
# Processing Record 48 of Set 7 | taltal
# Processing Record 49 of Set 7 | concepcion de buenos aires
# Processing Record 50 of Set 7 | trinidad
# Processing Record 1 of Set 8 | lerwick
# Processing Record 2 of Set 8 | broken hill
# Processing Record 3 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 4 of Set 8 | nadym
# Processing Record 5 of Set 8 | plouzane
# Processing Record 6 of Set 8 | vila
# Processing Record 7 of Set 8 | mount isa
# Processing Record 8 of Set 8 | raga
# Processing Record 9 of Set 8 | waipawa
# Processing Record 10 of Set 8 | mareeba
# Processing Record 11 of Set 8 | uyuni
# Processing Record 12 of Set 8 | sisimiut
# Processing Record 13 of Set 8 | san andres
# Processing Record 14 of Set 8 | magistralnyy
# Processing Record 15 of Set 8 | coquimbo
# Processing Record 16 of Set 8 | saint-pierre
# Processing Record 17 of Set 8 | richards bay
# Processing Record 18 of Set 8 | saurimo
# Processing Record 19 of Set 8 | caravelas
# Processing Record 20 of Set 8 | bundaberg
# Processing Record 21 of Set 8 | broome
# Processing Record 22 of Set 8 | narsaq
# Processing Record 23 of Set 8 | jasper
# Processing Record 24 of Set 8 | wete
# Processing Record 25 of Set 8 | pochinok
# Processing Record 26 of Set 8 | fortuna
# Processing Record 27 of Set 8 | chapais
# Processing Record 28 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 29 of Set 8 | meget
# Processing Record 30 of Set 8 | benghazi
# Processing Record 31 of Set 8 | bandarbeyla
# Processing Record 32 of Set 8 | payson
# Processing Record 33 of Set 8 | beachwood
# Processing Record 34 of Set 8 | quatre cocos
# Processing Record 35 of Set 8 | znin
# Processing Record 36 of Set 8 | bubaque
# Processing Record 37 of Set 8 | ilo
# Processing Record 38 of Set 8 | clyde river
# Processing Record 39 of Set 8 | muravlenko
# Processing Record 40 of Set 8 | vangaindrano
# Processing Record 41 of Set 8 | kloulklubed
# Processing Record 42 of Set 8 | quijingue
# Processing Record 43 of Set 8 | brownsville
# Processing Record 44 of Set 8 | buraydah
# Processing Record 45 of Set 8 | joensuu
# Processing Record 46 of Set 8 | verkhnevilyuysk
# Processing Record 47 of Set 8 | nevsehir
# Processing Record 48 of Set 8 | monte alegre
# Processing Record 49 of Set 8 | novyy karachay
# Processing Record 50 of Set 8 | rorvik
# Processing Record 1 of Set 9 | lensk
# Processing Record 2 of Set 9 | san lorenzo
# Processing Record 3 of Set 9 | rio grande
# Processing Record 4 of Set 9 | ancud
# Processing Record 5 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 9 | torres
# Processing Record 7 of Set 9 | sechura
# Processing Record 8 of Set 9 | kiboga
# Processing Record 9 of Set 9 | ayan
# Processing Record 10 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 11 of Set 9 | harbour breton
# Processing Record 12 of Set 9 | elizabeth city
# Processing Record 13 of Set 9 | tura
# Processing Record 14 of Set 9 | agua verde
# Processing Record 15 of Set 9 | manaure
# Processing Record 16 of Set 9 | talnakh
# Processing Record 17 of Set 9 | mantua
# Processing Record 18 of Set 9 | kimbe
# Processing Record 19 of Set 9 | el alto
# Processing Record 20 of Set 9 | vaitape
# Processing Record 21 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 22 of Set 9 | glenwood springs
# Processing Record 23 of Set 9 | santa rosa
# Processing Record 24 of Set 9 | pitimbu
# Processing Record 25 of Set 9 | inhambane
# Processing Record 26 of Set 9 | ontario
# Processing Record 27 of Set 9 | barranca
# Processing Record 28 of Set 9 | katherine
# Processing Record 29 of Set 9 | acarau
# Processing Record 30 of Set 9 | canalete
# Processing Record 31 of Set 9 | cosala
# Processing Record 32 of Set 9 | cockburn town
# Processing Record 33 of Set 9 | sarkand
# Processing Record 34 of Set 9 | igreja nova
# Processing Record 35 of Set 9 | disna
# Processing Record 36 of Set 9 | jiaojiang
# Processing Record 37 of Set 9 | araria
# Processing Record 38 of Set 9 | menongue
# Processing Record 39 of Set 9 | bantry
# Processing Record 40 of Set 9 | cabo san lucas
# Processing Record 41 of Set 9 | kavaratti
# Processing Record 42 of Set 9 | chumikan
# Processing Record 43 of Set 9 | airai
# Processing Record 44 of Set 9 | xai-xai
# Processing Record 45 of Set 9 | bud
# Processing Record 46 of Set 9 | herbrechtingen
# Processing Record 47 of Set 9 | ahipara
# Processing Record 48 of Set 9 | halifax
# Processing Record 49 of Set 9 | lupiro
# Processing Record 50 of Set 9 | nelson bay
# Processing Record 1 of Set 10 | taoudenni
# Processing Record 2 of Set 10 | qandala
# Processing Record 3 of Set 10 | astipalaia
# City not found. Skipping...
# Processing Record 4 of Set 10 | seoul
# Processing Record 5 of Set 10 | mecca
# Processing Record 6 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 10 | west bay
# Processing Record 9 of Set 10 | juneau
# Processing Record 10 of Set 10 | oria
# Processing Record 11 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 10 | okha
# Processing Record 13 of Set 10 | namibe
# Processing Record 14 of Set 10 | kawalu
# Processing Record 15 of Set 10 | zelenogorskiy
# Processing Record 16 of Set 10 | ekhabi
# Processing Record 17 of Set 10 | comodoro rivadavia
# Processing Record 18 of Set 10 | karaton
# Processing Record 19 of Set 10 | iqaluit
# Processing Record 20 of Set 10 | lugovoy
# Processing Record 21 of Set 10 | bakani
# Processing Record 22 of Set 10 | kencong
# Processing Record 23 of Set 10 | prior lake
# Processing Record 24 of Set 10 | busayra
# Processing Record 25 of Set 10 | saint-louis
# Processing Record 26 of Set 10 | maputo
# Processing Record 27 of Set 10 | takhtamygda
# Processing Record 28 of Set 10 | muncar
# Processing Record 29 of Set 10 | sidi bu zayd
# City not found. Skipping...
# Processing Record 30 of Set 10 | saint-marc
# Processing Record 31 of Set 10 | dudinka
# Processing Record 32 of Set 10 | harper
# Processing Record 33 of Set 10 | guaira
# Processing Record 34 of Set 10 | vallenar
# Processing Record 35 of Set 10 | chom bung
# City not found. Skipping...
# Processing Record 36 of Set 10 | dauphin
# Processing Record 37 of Set 10 | saint-leu
# Processing Record 38 of Set 10 | waingapu
# Processing Record 39 of Set 10 | nabire
# Processing Record 40 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 10 | cidreira
# Processing Record 42 of Set 10 | dicabisagan
# Processing Record 43 of Set 10 | asau
# Processing Record 44 of Set 10 | guerrero negro
# Processing Record 45 of Set 10 | ippy
# Processing Record 46 of Set 10 | colwyn bay
# Processing Record 47 of Set 10 | mackay
# Processing Record 48 of Set 10 | aljezur
# Processing Record 49 of Set 10 | bela
# Processing Record 50 of Set 10 | ikalamavony
# Processing Record 1 of Set 11 | nouadhibou
# Processing Record 2 of Set 11 | madang
# Processing Record 3 of Set 11 | karratha
# Processing Record 4 of Set 11 | paracuru
# Processing Record 5 of Set 11 | moyale
# Processing Record 6 of Set 11 | cariati
# Processing Record 7 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 11 | sola
# Processing Record 9 of Set 11 | san mateo ixtatan
# Processing Record 10 of Set 11 | moose factory
# Processing Record 11 of Set 11 | nakhon phanom
# Processing Record 12 of Set 11 | phalombe
# Processing Record 13 of Set 11 | lorengau
# Processing Record 14 of Set 11 | morro da fumaca
# Processing Record 15 of Set 11 | narrabri
# Processing Record 16 of Set 11 | boddam
# Processing Record 17 of Set 11 | zhuhai
# Processing Record 18 of Set 11 | muisne
# Processing Record 19 of Set 11 | puerto escondido
# Processing Record 20 of Set 11 | kilosa
# Processing Record 21 of Set 11 | llandrindod wells
# Processing Record 22 of Set 11 | christchurch
# Processing Record 23 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 24 of Set 11 | shakiso
# Processing Record 25 of Set 11 | shelburne
# Processing Record 26 of Set 11 | langenhagen
# Processing Record 27 of Set 11 | salaga
# Processing Record 28 of Set 11 | trairi
# Processing Record 29 of Set 11 | kaeo
# Processing Record 30 of Set 11 | krasnoselkup
# Processing Record 31 of Set 11 | pimentel
# Processing Record 32 of Set 11 | poum
# Processing Record 33 of Set 11 | woodburn
# Processing Record 34 of Set 11 | tommot
# Processing Record 35 of Set 11 | alexandria
# Processing Record 36 of Set 11 | ust-kuyga
# Processing Record 37 of Set 11 | husavik
# Processing Record 38 of Set 11 | melilla
# Processing Record 39 of Set 11 | zhezkazgan
# Processing Record 40 of Set 11 | barmer
# Processing Record 41 of Set 11 | mandalgovi
# Processing Record 42 of Set 11 | poltsamaa
# Processing Record 43 of Set 11 | gorin
# Processing Record 44 of Set 11 | the valley
# Processing Record 45 of Set 11 | nalut
# Processing Record 46 of Set 11 | batagay
# Processing Record 47 of Set 11 | alpena
# Processing Record 48 of Set 11 | abu kamal
# Processing Record 49 of Set 11 | faanui
# Processing Record 50 of Set 11 | tiznit
# Processing Record 1 of Set 12 | ngunguru
# Processing Record 2 of Set 12 | buzdyak
# Processing Record 3 of Set 12 | sawtell
# Processing Record 4 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 12 | dzhida
# Processing Record 6 of Set 12 | iquique
# Processing Record 7 of Set 12 | bayji
# Processing Record 8 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 12 | najran
# Processing Record 11 of Set 12 | beitbridge
# Processing Record 12 of Set 12 | maridi
# Processing Record 13 of Set 12 | strelka
# Processing Record 14 of Set 12 | sitka
# Processing Record 15 of Set 12 | nago
# Processing Record 16 of Set 12 | iracoubo
# Processing Record 17 of Set 12 | samarai
# Processing Record 18 of Set 12 | lithgow
# Processing Record 19 of Set 12 | palkaka
# City not found. Skipping...
# Processing Record 20 of Set 12 | weligama
# Processing Record 21 of Set 12 | katsuura
# Processing Record 22 of Set 12 | lagoa
# Processing Record 23 of Set 12 | ocean city
# Processing Record 24 of Set 12 | zhanakorgan
# Processing Record 25 of Set 12 | kampot
# Processing Record 26 of Set 12 | xuddur
# Processing Record 27 of Set 12 | hay river
# Processing Record 28 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 12 | santa isabel do rio negro
# Processing Record 30 of Set 12 | parsons
# Processing Record 31 of Set 12 | sioux lookout
# Processing Record 32 of Set 12 | puerto quijarro
# Processing Record 33 of Set 12 | sumbe
# Processing Record 34 of Set 12 | senanga
# Processing Record 35 of Set 12 | sabha
# Processing Record 36 of Set 12 | neuquen
# Processing Record 37 of Set 12 | plettenberg bay
# Processing Record 38 of Set 12 | ulaangom
# Processing Record 39 of Set 12 | wattegama
# Processing Record 40 of Set 12 | biak
# Processing Record 41 of Set 12 | burgeo
# Processing Record 42 of Set 12 | laguna
# Processing Record 43 of Set 12 | hailey
# Processing Record 44 of Set 12 | sinnamary
# Processing Record 45 of Set 12 | dubai
# Processing Record 46 of Set 12 | kazanskaya
# Processing Record 47 of Set 12 | smithers
# Processing Record 48 of Set 12 | nome
# Processing Record 49 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 50 of Set 12 | davydivka
# Processing Record 1 of Set 13 | asfi
# Processing Record 2 of Set 13 | varca
# Processing Record 3 of Set 13 | yar-sale
# Processing Record 4 of Set 13 | mustafabad
# Processing Record 5 of Set 13 | taga
# Processing Record 6 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 7 of Set 13 | tadine
# Processing Record 8 of Set 13 | gorontalo
# Processing Record 9 of Set 13 | pacific grove
# Processing Record 10 of Set 13 | gangakher
# Processing Record 11 of Set 13 | payo
# Processing Record 12 of Set 13 | ndola
# Processing Record 13 of Set 13 | aswan
# Processing Record 14 of Set 13 | constantine
# Processing Record 15 of Set 13 | puerto madryn
# Processing Record 16 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 13 | sao miguel do araguaia
# Processing Record 18 of Set 13 | idah
# Processing Record 19 of Set 13 | nioro
# Processing Record 20 of Set 13 | ponta delgada
# Processing Record 21 of Set 13 | ugoofaaru
# Processing Record 22 of Set 13 | yulara
# Processing Record 23 of Set 13 | san ramon
# Processing Record 24 of Set 13 | hamilton
# Processing Record 25 of Set 13 | vrsac
# Processing Record 26 of Set 13 | tambura
# Processing Record 27 of Set 13 | turtas
# Processing Record 28 of Set 13 | ittiri
# Processing Record 29 of Set 13 | kaohsiung
# Processing Record 30 of Set 13 | dongfeng
# Processing Record 31 of Set 13 | pameungpeuk
# Processing Record 32 of Set 13 | paramonga
# Processing Record 33 of Set 13 | luwuk
# Processing Record 34 of Set 13 | kirakira
# Processing Record 35 of Set 13 | noumea
# Processing Record 36 of Set 13 | laranjeiras do sul
# Processing Record 37 of Set 13 | leeuwarden
# Processing Record 38 of Set 13 | tatarbunary
# Processing Record 39 of Set 13 | takoradi
# Processing Record 40 of Set 13 | vanimo
# Processing Record 41 of Set 13 | port blair
# Processing Record 42 of Set 13 | mocuba
# Processing Record 43 of Set 13 | yangcun
# Processing Record 44 of Set 13 | usinsk
# Processing Record 45 of Set 13 | ballarat
# Processing Record 46 of Set 13 | manzil salim
# Processing Record 47 of Set 13 | fergus falls
# Processing Record 48 of Set 13 | sharjah
# Processing Record 49 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 13 | torbay
# Processing Record 1 of Set 14 | peleduy
# Processing Record 2 of Set 14 | roma
# Processing Record 3 of Set 14 | belyy yar
# Processing Record 4 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 5 of Set 14 | mbandaka
# Processing Record 6 of Set 14 | desnogorsk
# Processing Record 7 of Set 14 | miri
# Processing Record 8 of Set 14 | othonoi
# City not found. Skipping...
# Processing Record 9 of Set 14 | korogwe
# City not found. Skipping...
# Processing Record 10 of Set 14 | houston
# Processing Record 11 of Set 14 | cobija
# Processing Record 12 of Set 14 | lavrentiya
# Processing Record 13 of Set 14 | doha
# Processing Record 14 of Set 14 | berlevag
# Processing Record 15 of Set 14 | torit
# Processing Record 16 of Set 14 | celendin
# Processing Record 17 of Set 14 | beloha
# Processing Record 18 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 19 of Set 14 | wanaka
# Processing Record 20 of Set 14 | inuvik
# Processing Record 21 of Set 14 | leirvik
# Processing Record 22 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 14 | nelson
# Processing Record 24 of Set 14 | pokhara
# Processing Record 25 of Set 14 | churapcha
# Processing Record 26 of Set 14 | adrar
# Processing Record 27 of Set 14 | emerald
# Processing Record 28 of Set 14 | baykit
# Processing Record 29 of Set 14 | karczew
# Processing Record 30 of Set 14 | el dorado
# Processing Record 31 of Set 14 | brekstad
# Processing Record 32 of Set 14 | san vicente
# Processing Record 33 of Set 14 | guaruja
# Processing Record 34 of Set 14 | dongtai
# Processing Record 35 of Set 14 | japura
# Processing Record 36 of Set 14 | sirpur
# Processing Record 37 of Set 14 | russell
# Processing Record 38 of Set 14 | moerai
# Processing Record 39 of Set 14 | sandwick
# Processing Record 40 of Set 14 | lima
# Processing Record 41 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 42 of Set 14 | faridan
# City not found. Skipping...
# Processing Record 43 of Set 14 | atasu
# Processing Record 44 of Set 14 | belmonte
# Processing Record 45 of Set 14 | tahe
# Processing Record 46 of Set 14 | dutlwe
# Processing Record 47 of Set 14 | acapulco
# Processing Record 48 of Set 14 | ferrol
# Processing Record 49 of Set 14 | vodnyy
# Processing Record 50 of Set 14 | planeta rica
# Processing Record 1 of Set 15 | ola
# Processing Record 2 of Set 15 | eyrarbakki
# Processing Record 3 of Set 15 | amga
# Processing Record 4 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 5 of Set 15 | yabrud
# Processing Record 6 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 15 | tilichiki
# Processing Record 8 of Set 15 | mgandu
# Processing Record 9 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 10 of Set 15 | dalbandin
# Processing Record 11 of Set 15 | malatya
# Processing Record 12 of Set 15 | matamoros
# Processing Record 13 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 15 | fare
# Processing Record 15 of Set 15 | tupaciguara
# Processing Record 16 of Set 15 | kiama
# Processing Record 17 of Set 15 | odweyne
# Processing Record 18 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 15 | galle
# Processing Record 20 of Set 15 | ketchikan
# Processing Record 21 of Set 15 | aloleng
# Processing Record 22 of Set 15 | bairiki
# Processing Record 23 of Set 15 | west wendover
# Processing Record 24 of Set 15 | malpe
# Processing Record 25 of Set 15 | duluth
# Processing Record 26 of Set 15 | kanye
# Processing Record 27 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 28 of Set 15 | harnosand
# Processing Record 29 of Set 15 | monticello
# Processing Record 30 of Set 15 | redmond
# Processing Record 31 of Set 15 | sept-iles
# Processing Record 32 of Set 15 | san lawrenz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(5)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     New Norfolk      AU -42.7826  147.0587     41.72        75           3
# 1           Pevek      RU  69.7008  170.3133     39.24        86           7
# 2  Port Macquarie      AU -31.4333  152.9167     49.96        85           3
# 3   Mar Del Plata      AR -38.0023  -57.5575     50.02       100          90
# 4          Hobart      AU -42.8794  147.3294     42.06        79          20
#
#    Wind Speed
# 0        1.99
# 1       10.18
# 2        4.70
# 3        8.05
# 4        3.44

# %%
# 8. Export the DataFrame as a CSV file,
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV, that header will be present in the DataFrame
city_data_df.to_csv(output_data_file, index_label="City_ID")
