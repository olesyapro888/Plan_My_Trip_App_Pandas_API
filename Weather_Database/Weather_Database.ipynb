# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.

# %%
# Import the dependencies
import pandas as pd
import numpy as np
import requests

# Import the citipy module
from citipy import citipy

# Import the API key
from configW import weather_api_key

# %%
# 3. Create a new set of 2,000 random latitudes and longitude
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# Pack the latitudes and longitudes as pairs
lat_lngs = zip(lats, lngs)
# Create coordinates by adding the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 4. Get the nearest city using the citipy module.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# 5. Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0546ad5dbee13bad86394b7d864b452c

# %%
# 6. Retrieve the request information from the API call

# 6.a. Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# 6.b. Create counters. We want the first iteration of the logging for each recorded response and the set to start at 1
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# 6.c. Loop through all the cities in the list with enumerate() and reference the index and the city in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        #If the statement is true, then the set_count and the record_count are incremented by 1
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city with no blank spaces in the city name to avoid of finding the weather data for the first part of the city name.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count before the next city is processed.
    record_count += 1
    
    # Run an API request for each of the cities with "try-except" to prevent the API request from stopping prematurely.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Assign variables for each piece of data we need.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | poum
# Processing Record 2 of Set 1 | marzuq
# Processing Record 3 of Set 1 | ostrovnoy
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | maniitsoq
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | svetlogorsk
# Processing Record 13 of Set 1 | kirakira
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | montepuez
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | patti
# Processing Record 20 of Set 1 | baie-comeau
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | severo-kurilsk
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | dikson
# Processing Record 26 of Set 1 | gat
# Processing Record 27 of Set 1 | port hedland
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | zhezkazgan
# Processing Record 30 of Set 1 | georgetown
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 1 | airai
# Processing Record 35 of Set 1 | curup
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | coari
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | dongsheng
# Processing Record 41 of Set 1 | north platte
# Processing Record 42 of Set 1 | vao
# Processing Record 43 of Set 1 | salalah
# Processing Record 44 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | port augusta
# Processing Record 48 of Set 1 | flinders
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | egvekinot
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | namibe
# Processing Record 4 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 2 | laguna
# Processing Record 9 of Set 2 | notse
# Processing Record 10 of Set 2 | sorland
# Processing Record 11 of Set 2 | sabzevar
# Processing Record 12 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | cabo san lucas
# Processing Record 15 of Set 2 | coquimbo
# Processing Record 16 of Set 2 | cidreira
# Processing Record 17 of Set 2 | cherskiy
# Processing Record 18 of Set 2 | hofn
# Processing Record 19 of Set 2 | mangrol
# Processing Record 20 of Set 2 | kenai
# Processing Record 21 of Set 2 | aykhal
# Processing Record 22 of Set 2 | lavrentiya
# Processing Record 23 of Set 2 | saint-gabriel
# Processing Record 24 of Set 2 | katsuura
# Processing Record 25 of Set 2 | costa rica
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | sambava
# Processing Record 28 of Set 2 | labuhan
# Processing Record 29 of Set 2 | sfantu gheorghe
# Processing Record 30 of Set 2 | tessalit
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | shchelyayur
# City not found. Skipping...
# Processing Record 33 of Set 2 | flin flon
# Processing Record 34 of Set 2 | ancud
# Processing Record 35 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 2 | vaini
# Processing Record 38 of Set 2 | sawakin
# Processing Record 39 of Set 2 | port blair
# Processing Record 40 of Set 2 | sibolga
# Processing Record 41 of Set 2 | talesh
# City not found. Skipping...
# Processing Record 42 of Set 2 | wad madani
# Processing Record 43 of Set 2 | kavaratti
# Processing Record 44 of Set 2 | kruisfontein
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | hirara
# Processing Record 47 of Set 2 | de-kastri
# Processing Record 48 of Set 2 | odesskoye
# Processing Record 49 of Set 2 | alamosa
# Processing Record 50 of Set 2 | douglas
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | te anau
# Processing Record 3 of Set 3 | huazolotitlan
# City not found. Skipping...
# Processing Record 4 of Set 3 | nacogdoches
# Processing Record 5 of Set 3 | qaqortoq
# Processing Record 6 of Set 3 | ulundi
# Processing Record 7 of Set 3 | kiskunfelegyhaza
# Processing Record 8 of Set 3 | iracoubo
# Processing Record 9 of Set 3 | sept-iles
# Processing Record 10 of Set 3 | ossora
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | talnakh
# Processing Record 13 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 3 | ilulissat
# Processing Record 15 of Set 3 | isangel
# Processing Record 16 of Set 3 | gravdal
# Processing Record 17 of Set 3 | lata
# Processing Record 18 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 3 | lamballe
# Processing Record 20 of Set 3 | taoudenni
# Processing Record 21 of Set 3 | leh
# Processing Record 22 of Set 3 | nanortalik
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | high level
# Processing Record 25 of Set 3 | caravelas
# Processing Record 26 of Set 3 | khatanga
# Processing Record 27 of Set 3 | qesarya
# Processing Record 28 of Set 3 | santona
# Processing Record 29 of Set 3 | tanout
# Processing Record 30 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 3 | port alfred
# Processing Record 32 of Set 3 | tasiilaq
# Processing Record 33 of Set 3 | xapuri
# Processing Record 34 of Set 3 | faanui
# Processing Record 35 of Set 3 | aginskoye
# Processing Record 36 of Set 3 | lerwick
# Processing Record 37 of Set 3 | dhidhdhoo
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | golden
# Processing Record 40 of Set 3 | luckenwalde
# Processing Record 41 of Set 3 | castro
# Processing Record 42 of Set 3 | plouzane
# Processing Record 43 of Set 3 | san quintin
# Processing Record 44 of Set 3 | port lincoln
# Processing Record 45 of Set 3 | esperance
# Processing Record 46 of Set 3 | buraydah
# Processing Record 47 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 3 | henties bay
# Processing Record 49 of Set 3 | kibala
# Processing Record 50 of Set 3 | berdyaush
# Processing Record 1 of Set 4 | killybegs
# Processing Record 2 of Set 4 | kamennomostskoye
# Processing Record 3 of Set 4 | cape town
# Processing Record 4 of Set 4 | kaitangata
# Processing Record 5 of Set 4 | kutum
# Processing Record 6 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 7 of Set 4 | a
# City not found. Skipping...
# Processing Record 8 of Set 4 | pevek
# Processing Record 9 of Set 4 | neverkino
# Processing Record 10 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 4 | nome
# Processing Record 12 of Set 4 | the valley
# Processing Record 13 of Set 4 | bretigny-sur-orge
# Processing Record 14 of Set 4 | misawa
# Processing Record 15 of Set 4 | pocking
# Processing Record 16 of Set 4 | srivardhan
# Processing Record 17 of Set 4 | langham
# Processing Record 18 of Set 4 | shenkursk
# Processing Record 19 of Set 4 | bambanglipuro
# Processing Record 20 of Set 4 | bengkulu
# Processing Record 21 of Set 4 | japura
# Processing Record 22 of Set 4 | magadan
# Processing Record 23 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 4 | young
# Processing Record 25 of Set 4 | saint-leu
# Processing Record 26 of Set 4 | kawalu
# Processing Record 27 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 4 | shingu
# Processing Record 29 of Set 4 | kiruna
# Processing Record 30 of Set 4 | erenhot
# Processing Record 31 of Set 4 | meadow lake
# Processing Record 32 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 4 | porto novo
# Processing Record 34 of Set 4 | menongue
# Processing Record 35 of Set 4 | nizhniy kuranakh
# Processing Record 36 of Set 4 | puerto carreno
# Processing Record 37 of Set 4 | fomboni
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | aquiraz
# Processing Record 40 of Set 4 | sur
# Processing Record 41 of Set 4 | vangaindrano
# Processing Record 42 of Set 4 | avarua
# Processing Record 43 of Set 4 | sa kaeo
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | hithadhoo
# Processing Record 46 of Set 4 | cabangahan
# Processing Record 47 of Set 4 | antalaha
# Processing Record 48 of Set 4 | huaihua
# Processing Record 49 of Set 4 | vyatskiye polyany
# Processing Record 50 of Set 4 | maragogi
# Processing Record 1 of Set 5 | chadiza
# Processing Record 2 of Set 5 | batagay-alyta
# Processing Record 3 of Set 5 | la asuncion
# Processing Record 4 of Set 5 | gebre guracha
# Processing Record 5 of Set 5 | san cristobal
# Processing Record 6 of Set 5 | rabo de peixe
# Processing Record 7 of Set 5 | saint george
# Processing Record 8 of Set 5 | college
# Processing Record 9 of Set 5 | pacific grove
# Processing Record 10 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 5 | klaksvik
# Processing Record 12 of Set 5 | pauini
# Processing Record 13 of Set 5 | comodoro rivadavia
# Processing Record 14 of Set 5 | iqaluit
# Processing Record 15 of Set 5 | iquique
# Processing Record 16 of Set 5 | tommot
# Processing Record 17 of Set 5 | barra do garcas
# Processing Record 18 of Set 5 | sitka
# Processing Record 19 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 5 | tekeli
# Processing Record 21 of Set 5 | thompson
# Processing Record 22 of Set 5 | tigil
# Processing Record 23 of Set 5 | ewa beach
# Processing Record 24 of Set 5 | bela
# Processing Record 25 of Set 5 | deputatskiy
# Processing Record 26 of Set 5 | marystown
# Processing Record 27 of Set 5 | vanimo
# Processing Record 28 of Set 5 | grand gaube
# Processing Record 29 of Set 5 | arvika
# Processing Record 30 of Set 5 | longyearbyen
# Processing Record 31 of Set 5 | champerico
# Processing Record 32 of Set 5 | kavieng
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | urumqi
# Processing Record 35 of Set 5 | arcata
# Processing Record 36 of Set 5 | goderich
# Processing Record 37 of Set 5 | la ronge
# Processing Record 38 of Set 5 | olinda
# Processing Record 39 of Set 5 | dabhol
# Processing Record 40 of Set 5 | lagoa
# Processing Record 41 of Set 5 | marquette
# Processing Record 42 of Set 5 | bredasdorp
# Processing Record 43 of Set 5 | tual
# Processing Record 44 of Set 5 | iskateley
# Processing Record 45 of Set 5 | fortuna
# Processing Record 46 of Set 5 | san vicente
# Processing Record 47 of Set 5 | colquechaca
# Processing Record 48 of Set 5 | basoko
# Processing Record 49 of Set 5 | burica
# City not found. Skipping...
# Processing Record 50 of Set 5 | kodiak
# Processing Record 1 of Set 6 | puerto escondido
# Processing Record 2 of Set 6 | tiksi
# Processing Record 3 of Set 6 | college station
# Processing Record 4 of Set 6 | haines junction
# Processing Record 5 of Set 6 | leningradskiy
# Processing Record 6 of Set 6 | kahului
# Processing Record 7 of Set 6 | noumea
# Processing Record 8 of Set 6 | chuy
# Processing Record 9 of Set 6 | asau
# Processing Record 10 of Set 6 | geraldton
# Processing Record 11 of Set 6 | chishtian mandi
# Processing Record 12 of Set 6 | camacha
# Processing Record 13 of Set 6 | yar-sale
# Processing Record 14 of Set 6 | berbera
# Processing Record 15 of Set 6 | mount gambier
# Processing Record 16 of Set 6 | belaya gora
# Processing Record 17 of Set 6 | saint-augustin
# Processing Record 18 of Set 6 | vardo
# Processing Record 19 of Set 6 | vitim
# Processing Record 20 of Set 6 | grindavik
# Processing Record 21 of Set 6 | sidi ali
# Processing Record 22 of Set 6 | clyde river
# Processing Record 23 of Set 6 | nacala
# Processing Record 24 of Set 6 | aljezur
# Processing Record 25 of Set 6 | barcelos
# Processing Record 26 of Set 6 | kazanka
# Processing Record 27 of Set 6 | birjand
# Processing Record 28 of Set 6 | pisco
# Processing Record 29 of Set 6 | tunxi
# City not found. Skipping...
# Processing Record 30 of Set 6 | bloemhof
# Processing Record 31 of Set 6 | faya
# Processing Record 32 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 33 of Set 6 | najran
# Processing Record 34 of Set 6 | coria
# Processing Record 35 of Set 6 | provideniya
# Processing Record 36 of Set 6 | vestmannaeyjar
# Processing Record 37 of Set 6 | ponta delgada
# Processing Record 38 of Set 6 | waipawa
# Processing Record 39 of Set 6 | mishelevka
# Processing Record 40 of Set 6 | bubaque
# Processing Record 41 of Set 6 | meulaboh
# Processing Record 42 of Set 6 | belyy yar
# Processing Record 43 of Set 6 | cabadiangan
# Processing Record 44 of Set 6 | bagotville
# Processing Record 45 of Set 6 | la seyne-sur-mer
# Processing Record 46 of Set 6 | hamilton
# Processing Record 47 of Set 6 | lorengau
# Processing Record 48 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 6 | okha
# Processing Record 50 of Set 6 | san patricio
# Processing Record 1 of Set 7 | viedma
# Processing Record 2 of Set 7 | amahai
# Processing Record 3 of Set 7 | kez
# Processing Record 4 of Set 7 | winslow
# Processing Record 5 of Set 7 | yatou
# Processing Record 6 of Set 7 | port hardy
# Processing Record 7 of Set 7 | bandarbeyla
# Processing Record 8 of Set 7 | lovozero
# Processing Record 9 of Set 7 | sisimiut
# Processing Record 10 of Set 7 | evensk
# Processing Record 11 of Set 7 | bull savanna
# Processing Record 12 of Set 7 | caranavi
# Processing Record 13 of Set 7 | mbekenyera
# Processing Record 14 of Set 7 | akureyri
# Processing Record 15 of Set 7 | marovoay
# Processing Record 16 of Set 7 | anchorage
# Processing Record 17 of Set 7 | nouadhibou
# Processing Record 18 of Set 7 | fort nelson
# Processing Record 19 of Set 7 | bharatpur
# Processing Record 20 of Set 7 | tandur
# Processing Record 21 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 7 | atar
# Processing Record 23 of Set 7 | arkhangelos
# City not found. Skipping...
# Processing Record 24 of Set 7 | turtas
# Processing Record 25 of Set 7 | yaan
# Processing Record 26 of Set 7 | tura
# Processing Record 27 of Set 7 | gaoual
# Processing Record 28 of Set 7 | xai-xai
# Processing Record 29 of Set 7 | uzhhorod
# Processing Record 30 of Set 7 | muroto
# Processing Record 31 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 32 of Set 7 | rio grande
# Processing Record 33 of Set 7 | oyama
# Processing Record 34 of Set 7 | nanakuli
# Processing Record 35 of Set 7 | atambua
# Processing Record 36 of Set 7 | mount isa
# Processing Record 37 of Set 7 | buala
# Processing Record 38 of Set 7 | abu kamal
# Processing Record 39 of Set 7 | eatonton
# Processing Record 40 of Set 7 | chokurdakh
# Processing Record 41 of Set 7 | anar darreh
# City not found. Skipping...
# Processing Record 42 of Set 7 | yulara
# Processing Record 43 of Set 7 | norman wells
# Processing Record 44 of Set 7 | umarkot
# Processing Record 45 of Set 7 | avera
# Processing Record 46 of Set 7 | heias
# City not found. Skipping...
# Processing Record 47 of Set 7 | barkly west
# Processing Record 48 of Set 7 | matsanga
# City not found. Skipping...
# Processing Record 49 of Set 7 | killeen
# Processing Record 50 of Set 7 | basqal
# Processing Record 1 of Set 8 | madoc
# Processing Record 2 of Set 8 | mpika
# Processing Record 3 of Set 8 | kloulklubed
# Processing Record 4 of Set 8 | turukhansk
# Processing Record 5 of Set 8 | verkhoyansk
# Processing Record 6 of Set 8 | sungaipenuh
# Processing Record 7 of Set 8 | timizart
# Processing Record 8 of Set 8 | mazagao
# Processing Record 9 of Set 8 | oil city
# Processing Record 10 of Set 8 | kaabong
# Processing Record 11 of Set 8 | broome
# Processing Record 12 of Set 8 | ensley
# Processing Record 13 of Set 8 | ugoofaaru
# Processing Record 14 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 15 of Set 8 | tocopilla
# Processing Record 16 of Set 8 | waingapu
# Processing Record 17 of Set 8 | sinfra
# Processing Record 18 of Set 8 | chigasaki
# Processing Record 19 of Set 8 | quetta
# Processing Record 20 of Set 8 | khani
# Processing Record 21 of Set 8 | santa cruz de la palma
# Processing Record 22 of Set 8 | grand-santi
# Processing Record 23 of Set 8 | carnarvon
# Processing Record 24 of Set 8 | laramie
# Processing Record 25 of Set 8 | diffa
# Processing Record 26 of Set 8 | beira
# Processing Record 27 of Set 8 | vila franca do campo
# Processing Record 28 of Set 8 | cayenne
# Processing Record 29 of Set 8 | falmouth
# Processing Record 30 of Set 8 | bontang
# Processing Record 31 of Set 8 | constitucion
# Processing Record 32 of Set 8 | buchanan
# Processing Record 33 of Set 8 | markova
# Processing Record 34 of Set 8 | buin
# Processing Record 35 of Set 8 | mount darwin
# Processing Record 36 of Set 8 | harper
# Processing Record 37 of Set 8 | zhigansk
# Processing Record 38 of Set 8 | kurskaya
# Processing Record 39 of Set 8 | yantzaza
# Processing Record 40 of Set 8 | miyako
# Processing Record 41 of Set 8 | arlit
# Processing Record 42 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 8 | mossendjo
# Processing Record 44 of Set 8 | luanda
# Processing Record 45 of Set 8 | matagami
# Processing Record 46 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 8 | eldorado
# Processing Record 48 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 8 | chulman
# Processing Record 50 of Set 8 | westport
# Processing Record 1 of Set 9 | nelson bay
# Processing Record 2 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 9 | tolosa
# Processing Record 4 of Set 9 | shubarkuduk
# Processing Record 5 of Set 9 | prado
# Processing Record 6 of Set 9 | zalantun
# Processing Record 7 of Set 9 | kidal
# Processing Record 8 of Set 9 | braslav
# City not found. Skipping...
# Processing Record 9 of Set 9 | hasaki
# Processing Record 10 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 9 | victor harbor
# Processing Record 12 of Set 9 | touros
# Processing Record 13 of Set 9 | trincomalee
# Processing Record 14 of Set 9 | beringovskiy
# Processing Record 15 of Set 9 | bambous virieux
# Processing Record 16 of Set 9 | iranshahr
# Processing Record 17 of Set 9 | paamiut
# Processing Record 18 of Set 9 | pontes e lacerda
# Processing Record 19 of Set 9 | safaga
# Processing Record 20 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 21 of Set 9 | ouro preto do oeste
# Processing Record 22 of Set 9 | leshukonskoye
# Processing Record 23 of Set 9 | okhotsk
# Processing Record 24 of Set 9 | tuatapere
# Processing Record 25 of Set 9 | high river
# Processing Record 26 of Set 9 | lashio
# Processing Record 27 of Set 9 | lubao
# Processing Record 28 of Set 9 | tres arroyos
# Processing Record 29 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 9 | half moon bay
# Processing Record 31 of Set 9 | abengourou
# Processing Record 32 of Set 9 | eureka
# Processing Record 33 of Set 9 | adrar
# Processing Record 34 of Set 9 | nisia floresta
# Processing Record 35 of Set 9 | vieques
# Processing Record 36 of Set 9 | phonhong
# Processing Record 37 of Set 9 | tadine
# Processing Record 38 of Set 9 | riyadh
# Processing Record 39 of Set 9 | kununurra
# Processing Record 40 of Set 9 | verkh-usugli
# Processing Record 41 of Set 9 | brejo da madre de deus
# Processing Record 42 of Set 9 | victoria
# Processing Record 43 of Set 9 | guiratinga
# Processing Record 44 of Set 9 | hearst
# Processing Record 45 of Set 9 | kifri
# Processing Record 46 of Set 9 | saint-georges
# Processing Record 47 of Set 9 | mezen
# Processing Record 48 of Set 9 | morinville
# Processing Record 49 of Set 9 | sao filipe
# Processing Record 50 of Set 9 | plettenberg bay
# Processing Record 1 of Set 10 | bathsheba
# Processing Record 2 of Set 10 | saint albans
# Processing Record 3 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 10 | portland
# Processing Record 5 of Set 10 | saint anthony
# Processing Record 6 of Set 10 | lehola
# Processing Record 7 of Set 10 | isla mujeres
# Processing Record 8 of Set 10 | samarai
# Processing Record 9 of Set 10 | pampas
# Processing Record 10 of Set 10 | wuan
# Processing Record 11 of Set 10 | saldanha
# Processing Record 12 of Set 10 | bonavista
# Processing Record 13 of Set 10 | gizo
# Processing Record 14 of Set 10 | pacifica
# Processing Record 15 of Set 10 | ilinskiy
# Processing Record 16 of Set 10 | kasamwa
# Processing Record 17 of Set 10 | singaraja
# Processing Record 18 of Set 10 | soyo
# Processing Record 19 of Set 10 | ust-tsilma
# Processing Record 20 of Set 10 | korla
# Processing Record 21 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 22 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 23 of Set 10 | monterey
# Processing Record 24 of Set 10 | yining
# Processing Record 25 of Set 10 | bone
# Processing Record 26 of Set 10 | corozal
# Processing Record 27 of Set 10 | corinto
# Processing Record 28 of Set 10 | luderitz
# Processing Record 29 of Set 10 | batagay
# Processing Record 30 of Set 10 | smolenka
# Processing Record 31 of Set 10 | thinadhoo
# Processing Record 32 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 10 | ponta do sol
# Processing Record 34 of Set 10 | mumford
# Processing Record 35 of Set 10 | sao joao da barra
# Processing Record 36 of Set 10 | nhulunbuy
# Processing Record 37 of Set 10 | sechura
# Processing Record 38 of Set 10 | alta floresta
# Processing Record 39 of Set 10 | kasama
# Processing Record 40 of Set 10 | port hawkesbury
# Processing Record 41 of Set 10 | bom despacho
# Processing Record 42 of Set 10 | iralaya
# Processing Record 43 of Set 10 | kokoda
# Processing Record 44 of Set 10 | mabaruma
# Processing Record 45 of Set 10 | alihe
# Processing Record 46 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 10 | merke
# Processing Record 48 of Set 10 | bejucal
# Processing Record 49 of Set 10 | jaisalmer
# Processing Record 50 of Set 10 | saint-pierre
# Processing Record 1 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 2 of Set 11 | kokopo
# Processing Record 3 of Set 11 | valpacos
# Processing Record 4 of Set 11 | ribeira grande
# Processing Record 5 of Set 11 | saryg-sep
# Processing Record 6 of Set 11 | port moresby
# Processing Record 7 of Set 11 | ayagoz
# Processing Record 8 of Set 11 | klyuchi
# Processing Record 9 of Set 11 | aguimes
# Processing Record 10 of Set 11 | shimoda
# Processing Record 11 of Set 11 | raikot
# Processing Record 12 of Set 11 | murray bridge
# Processing Record 13 of Set 11 | shelabolikha
# Processing Record 14 of Set 11 | broken hill
# Processing Record 15 of Set 11 | corn island
# Processing Record 16 of Set 11 | lahij
# Processing Record 17 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 11 | ulundurpettai
# City not found. Skipping...
# Processing Record 19 of Set 11 | katobu
# Processing Record 20 of Set 11 | gunjur
# Processing Record 21 of Set 11 | havoysund
# Processing Record 22 of Set 11 | wanaka
# Processing Record 23 of Set 11 | verkhnyaya inta
# Processing Record 24 of Set 11 | ekibastuz
# Processing Record 25 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 11 | barkhan
# Processing Record 27 of Set 11 | kailua
# Processing Record 28 of Set 11 | qui nhon
# Processing Record 29 of Set 11 | elizabeth city
# Processing Record 30 of Set 11 | akyab
# Processing Record 31 of Set 11 | jiwani
# Processing Record 32 of Set 11 | porto recanati
# Processing Record 33 of Set 11 | pafos
# Processing Record 34 of Set 11 | mentougou
# Processing Record 35 of Set 11 | dingle
# Processing Record 36 of Set 11 | manokwari
# Processing Record 37 of Set 11 | ocosingo
# Processing Record 38 of Set 11 | kieta
# Processing Record 39 of Set 11 | ouallam
# Processing Record 40 of Set 11 | dicabisagan
# Processing Record 41 of Set 11 | ipixuna
# Processing Record 42 of Set 11 | san ramon
# Processing Record 43 of Set 11 | bo phloi
# Processing Record 44 of Set 11 | miastko
# Processing Record 45 of Set 11 | tibati
# Processing Record 46 of Set 11 | le port
# Processing Record 47 of Set 11 | vila velha
# Processing Record 48 of Set 11 | zarya
# Processing Record 49 of Set 11 | arnedo
# Processing Record 50 of Set 11 | nemuro
# Processing Record 1 of Set 12 | djambala
# Processing Record 2 of Set 12 | talcahuano
# Processing Record 3 of Set 12 | agaro
# Processing Record 4 of Set 12 | oeiras do para
# Processing Record 5 of Set 12 | manali
# Processing Record 6 of Set 12 | dekoa
# City not found. Skipping...
# Processing Record 7 of Set 12 | santa maria da vitoria
# Processing Record 8 of Set 12 | grahamstown
# Processing Record 9 of Set 12 | roald
# Processing Record 10 of Set 12 | salta
# Processing Record 11 of Set 12 | angra
# City not found. Skipping...
# Processing Record 12 of Set 12 | scottsbluff
# Processing Record 13 of Set 12 | xining
# Processing Record 14 of Set 12 | landerneau
# Processing Record 15 of Set 12 | outlook
# Processing Record 16 of Set 12 | aksha
# Processing Record 17 of Set 12 | manzhouli
# Processing Record 18 of Set 12 | ampanihy
# Processing Record 19 of Set 12 | kumbo
# Processing Record 20 of Set 12 | narathiwat
# Processing Record 21 of Set 12 | kurilsk
# Processing Record 22 of Set 12 | prescott
# Processing Record 23 of Set 12 | ivankiv
# Processing Record 24 of Set 12 | vyazma
# Processing Record 25 of Set 12 | ranot
# Processing Record 26 of Set 12 | sandy bay
# Processing Record 27 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 28 of Set 12 | poronaysk
# Processing Record 29 of Set 12 | purranque
# Processing Record 30 of Set 12 | aklavik
# Processing Record 31 of Set 12 | osakarovka
# Processing Record 32 of Set 12 | lolodorf
# Processing Record 33 of Set 12 | awjilah
# Processing Record 34 of Set 12 | berdigestyakh
# Processing Record 35 of Set 12 | san carlos
# Processing Record 36 of Set 12 | krikellos
# Processing Record 37 of Set 12 | erdenet
# Processing Record 38 of Set 12 | altus
# Processing Record 39 of Set 12 | xinqing
# Processing Record 40 of Set 12 | ambilobe
# Processing Record 41 of Set 12 | nahavand
# Processing Record 42 of Set 12 | walvis bay
# Processing Record 43 of Set 12 | yumen
# Processing Record 44 of Set 12 | elat
# Processing Record 45 of Set 12 | los llanos de aridane
# Processing Record 46 of Set 12 | mocuba
# Processing Record 47 of Set 12 | ola
# Processing Record 48 of Set 12 | nikolayevsk-na-amure
# Processing Record 49 of Set 12 | praia da vitoria
# Processing Record 50 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 1 of Set 13 | necochea
# Processing Record 2 of Set 13 | north bend
# Processing Record 3 of Set 13 | koumac
# Processing Record 4 of Set 13 | itarema
# Processing Record 5 of Set 13 | santa rita
# Processing Record 6 of Set 13 | mulege
# Processing Record 7 of Set 13 | palu
# Processing Record 8 of Set 13 | auburn
# Processing Record 9 of Set 13 | biak
# Processing Record 10 of Set 13 | lisala
# Processing Record 11 of Set 13 | aurangabad
# Processing Record 12 of Set 13 | teneguiban
# City not found. Skipping...
# Processing Record 13 of Set 13 | mogadishu
# Processing Record 14 of Set 13 | pangai
# Processing Record 15 of Set 13 | saint-francois
# Processing Record 16 of Set 13 | narrabri
# Processing Record 17 of Set 13 | sioux lookout
# Processing Record 18 of Set 13 | nyurba
# Processing Record 19 of Set 13 | thunder bay
# Processing Record 20 of Set 13 | xudat
# Processing Record 21 of Set 13 | lufilufi
# Processing Record 22 of Set 13 | ornskoldsvik
# Processing Record 23 of Set 13 | husavik
# Processing Record 24 of Set 13 | teya
# Processing Record 25 of Set 13 | andenes
# Processing Record 26 of Set 13 | fayaoue
# Processing Record 27 of Set 13 | udobnaya
# Processing Record 28 of Set 13 | eyl
# Processing Record 29 of Set 13 | chapais
# Processing Record 30 of Set 13 | ypsonas
# Processing Record 31 of Set 13 | vestmanna
# Processing Record 32 of Set 13 | shuyskoye
# Processing Record 33 of Set 13 | souris
# Processing Record 34 of Set 13 | muyezerskiy
# Processing Record 35 of Set 13 | majene
# Processing Record 36 of Set 13 | colares
# Processing Record 37 of Set 13 | maiduguri
# Processing Record 38 of Set 13 | prince rupert
# Processing Record 39 of Set 13 | nizhniy odes
# Processing Record 40 of Set 13 | ust-kuyga
# Processing Record 41 of Set 13 | weligama
# Processing Record 42 of Set 13 | slave lake
# Processing Record 43 of Set 13 | calabozo
# Processing Record 44 of Set 13 | shenjiamen
# Processing Record 45 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 13 | edmundston
# Processing Record 47 of Set 13 | sinnamary
# Processing Record 48 of Set 13 | acajutla
# Processing Record 49 of Set 13 | margate
# Processing Record 50 of Set 13 | gidole
# Processing Record 1 of Set 14 | mecca
# Processing Record 2 of Set 14 | nara
# Processing Record 3 of Set 14 | samarkand
# Processing Record 4 of Set 14 | pitimbu
# Processing Record 5 of Set 14 | camana
# Processing Record 6 of Set 14 | roblin
# Processing Record 7 of Set 14 | changde
# Processing Record 8 of Set 14 | san policarpo
# Processing Record 9 of Set 14 | zaraza
# Processing Record 10 of Set 14 | mao
# Processing Record 11 of Set 14 | anloga
# Processing Record 12 of Set 14 | carutapera
# Processing Record 13 of Set 14 | odessa
# Processing Record 14 of Set 14 | virginia beach
# Processing Record 15 of Set 14 | boulder city
# Processing Record 16 of Set 14 | alexandria
# Processing Record 17 of Set 14 | flers
# Processing Record 18 of Set 14 | sorong
# Processing Record 19 of Set 14 | terrace bay
# Processing Record 20 of Set 14 | jardim
# Processing Record 21 of Set 14 | thiruvananthapuram
# Processing Record 22 of Set 14 | rocha
# Processing Record 23 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 24 of Set 14 | beloha
# Processing Record 25 of Set 14 | kathmandu
# Processing Record 26 of Set 14 | balad
# Processing Record 27 of Set 14 | yataity
# Processing Record 28 of Set 14 | kingaroy
# Processing Record 29 of Set 14 | vila
# Processing Record 30 of Set 14 | ouango
# Processing Record 31 of Set 14 | tateyama
# Processing Record 32 of Set 14 | hauterive
# Processing Record 33 of Set 14 | zyryanka
# Processing Record 34 of Set 14 | aleksandrov gay
# Processing Record 35 of Set 14 | acapulco
# Processing Record 36 of Set 14 | olafsvik
# Processing Record 37 of Set 14 | pagman
# City not found. Skipping...
# Processing Record 38 of Set 14 | pa sang
# Processing Record 39 of Set 14 | uruzgan
# Processing Record 40 of Set 14 | atasu
# Processing Record 41 of Set 14 | cuyo
# Processing Record 42 of Set 14 | gardan diwal
# City not found. Skipping...
# Processing Record 43 of Set 14 | san jose
# Processing Record 44 of Set 14 | salinopolis
# Processing Record 45 of Set 14 | gatehouse of fleet
# Processing Record 46 of Set 14 | dunedin
# Processing Record 47 of Set 14 | palma di montechiaro
# Processing Record 48 of Set 14 | santa rosa
# Processing Record 49 of Set 14 | puerto madryn
# Processing Record 50 of Set 14 | ariquemes
# Processing Record 1 of Set 15 | komsomolskiy
# Processing Record 2 of Set 15 | yunguyo
# Processing Record 3 of Set 15 | ushtobe
# Processing Record 4 of Set 15 | cockburn town
# Processing Record 5 of Set 15 | lasa
# Processing Record 6 of Set 15 | numan
# Processing Record 7 of Set 15 | shieli
# Processing Record 8 of Set 15 | toora-khem
# Processing Record 9 of Set 15 | balaipungut
# Processing Record 10 of Set 15 | lhuntshi
# City not found. Skipping...
# Processing Record 11 of Set 15 | alyangula
# Processing Record 12 of Set 15 | ishigaki
# Processing Record 13 of Set 15 | toktogul
# Processing Record 14 of Set 15 | brisbane
# Processing Record 15 of Set 15 | christchurch
# Processing Record 16 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 17 of Set 15 | mirabad
# Processing Record 18 of Set 15 | codrington
# Processing Record 19 of Set 15 | gemena
# Processing Record 20 of Set 15 | nizwa
# Processing Record 21 of Set 15 | aviles
# Processing Record 22 of Set 15 | yangcun
# Processing Record 23 of Set 15 | zabid
# Processing Record 24 of Set 15 | kapuskasing
# Processing Record 25 of Set 15 | hualmay
# Processing Record 26 of Set 15 | visnes
# Processing Record 27 of Set 15 | nerchinsk
# Processing Record 28 of Set 15 | jiazi
# Processing Record 29 of Set 15 | thessalon
# Processing Record 30 of Set 15 | moose factory
# Processing Record 31 of Set 15 | guerrero negro
# Processing Record 32 of Set 15 | pascagoula
# Processing Record 33 of Set 15 | ust-kulom
# Processing Record 34 of Set 15 | santa maria
# Processing Record 35 of Set 15 | manjeshwar
# Processing Record 36 of Set 15 | chicama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Poum      NC -20.2333  164.0167     70.56        67         100
# 1         Marzuq      YE  14.4000   46.4667     84.74        34          89
# 2      Ostrovnoy      RU  68.0531   39.5131     54.27        79           5
# 3    Yellowknife      CA  62.4560 -114.3525     59.52        67          90
# 4        Mataura      NZ -46.1927  168.8643     38.48        89         100
# ..           ...     ...      ...       ...       ...       ...         ...
# 667   Pascagoula      US  30.3658  -88.5561     87.85        75           7
# 668    Ust-Kulom      RU  61.6864   53.6902     43.11        98           5
# 669  Santa Maria      BR -29.6842  -53.8069     65.30        79           0
# 670   Manjeshwar      IN  12.7194   74.8861     76.28        87         100
# 671      Chicama      PE  -7.8447  -79.1469     64.54        81          16
#
#      Wind Speed Current Description
# 0          5.99     overcast clouds
# 1          6.58     overcast clouds
# 2          9.55           clear sky
# 3         25.32     overcast clouds
# 4          1.39     overcast clouds
# ..          ...                 ...
# 667        7.83           clear sky
# 668        4.88           clear sky
# 669        5.77           clear sky
# 670        1.23     overcast clouds
# 671        9.82          few clouds
#
# [672 rows x 9 columns]

# %%
# 8. Export the DataFrame as a CSV file,
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV, that header will be present in the DataFrame
city_data_df.to_csv(output_data_file, index_label="City_ID")
